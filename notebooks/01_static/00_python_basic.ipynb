# %% [markdown]
# # 예외처리
# -문법
# ```python
# try:
#     예외 발생 가능한 명령어
# except:
#     예외 발생했을 때, 실행할 명령어
# else:
#     예외가 발생하지 않았을 때, 실행할 명령어
# finally:
#     예외 발생 여부와 상관없이, 마지막 실행할 명령어
# ```

# %%
lt = [1, 3, 5]

lt[1]
# Out:
# 3

# %%
lt[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 lt[4]
#
# IndexError: list index out of range

# %%
n1, n2 = eval(input('정수 2개 입력 : '))
print(f'{n1 = }, {n2 = }')
print(f'{type(n1) = }, {type(n2) = }')

result1 = n1 // n2
result2 = n1 % n2

print('몫 :', result1)
print('나머지 :', result2)

print('** 프로그램 종료 **')
# Out:
# 정수 2개 입력 :  5, 0
# n1 = 5, n2 = 0
# type(n1) = <class 'int'>, type(n2) = <class 'int'>
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[13], line 5
#       1 n1, n2 = eval(input('정수 2개 입력 : '))
#       2 print(f'{n1 = }, {n2 = }')
#       3 print(f'{type(n1) = }, {type(n2) = }')
#       4
# ----> 5 result1 = n1 // n2
#       6 result2 = n1 % n2
#       7
#       8 print('몫 :', result1)
#
# ZeroDivisionError: integer division or modulo by zero

# %%
n1, n2 = eval(input('정수 2개 입력 : '))
print(f'{n1 = }, {n2 = }')
print(f'{type(n1) = }, {type(n2) = }')

try:
    ## 예외 발생 가능한 명령어
    result1 = n1 // n2
    result2 = n1 % n2
except:
    ## 예외 발생했을 때, 실행할 명령어
    print('분모가 0으로 계산 불능')
else:
    ## 예외가 발생하지 않았을 때, 실행할 명령어
    print('몫 :', result1)
    print('나머지 :', result2)
finally:
    ## 예외 발생 여부와 상관없이, 마지막에 실행할 명령어
    print('>> 예외처리 구문 종료 <<')


print()
print('** 프로그램 종료 **')
# Out:
# 정수 2개 입력 :  5, 0
# n1 = 5, n2 = 0
# type(n1) = <class 'int'>, type(n2) = <class 'int'>
# 분모가 0으로 계산 불능
# >> 예외처리 구문 종료 <<
#
# ** 프로그램 종료 **

# %%
n1, n2 = eval(input('정수 2개 입력 : '))
print(f'{n1 = }, {n2 = }')
print(f'{type(n1) = }, {type(n2) = }')

try:
    ## 예외 발생 가능한 명령어
    result1 = n1 // n2
    result2 = n1 % n2
    print('몫 :', result1)
    print('나머지 :', result2)
except:
    ## 예외 발생했을 때, 실행할 명령어
    print('분모가 0으로 계산 불능')
finally:
    ## 예외 발생 여부와 상관없이, 마지막에 실행할 명령어
    print('>> 예외처리 구문 종료 <<')


print()
print('** 프로그램 종료 **')
# Out:
# 정수 2개 입력 :  5, 0
# n1 = 5, n2 = 0
# type(n1) = <class 'int'>, type(n2) = <class 'int'>
# 분모가 0으로 계산 불능
# >> 예외처리 구문 종료 <<
#
# ** 프로그램 종료 **

# %%
n1, n2 = eval(input('정수 2개 입력 : '))
print(f'{n1 = }, {n2 = }')
print(f'{type(n1) = }, {type(n2) = }')

try:
    ## 예외 발생 가능한 명령어
    result1 = n1 // n2
    result2 = n1 % n2
    print('몫 :', result1)
    print('나머지 :', result2)
except:
    ## 예외 발생했을 때, 실행할 명령어
    print('분모가 0으로 계산 불능')


print()
print('** 프로그램 종료 **')
# Out:
# 정수 2개 입력 :  5, 0
# n1 = 5, n2 = 0
# type(n1) = <class 'int'>, type(n2) = <class 'int'>
# 분모가 0으로 계산 불능
#
# ** 프로그램 종료 **

# %%
n1, n2 = eval(input('정수 2개 입력 : '))
print()

try:
    ## 예외 발생 가능한 명령어
    result1 = n1 // n2
    result2 = n1 % n2
except IndexError:
    print('인덱스의 범위를 벗어났습니다.')
except ZeroDivisionError as error:
    ## 예외 발생했을 때, 실행할 명령어
    print('분모가 0으로 계산 불능입니다.')
    print(error)
else:
    print('몫 :', result1)
    print('나머지 :', result2)
    

print()
print('** 프로그램 종료 **')
# Out:
# 정수 2개 입력 :  5, 0
# 분모가 0으로 계산 불능
# integer division or modulo by zero
#
# ** 프로그램 종료 **

# %% [markdown]
# # 문제1

# %%
list_value = ['100', 'good', '5', '250', 'hi', '500']
list_num = []

# %%
## 예외처리를 이용하여, 코드 작성
for value in list_value:
    try:
        int(value)
        list_num.append(value)
    except:
        pass

# %%
## 출력 : ['100', '5', '250', '500']
list_num
# Out:
# ['100', '5', '250', '500']

# %% [markdown]
# # 문제2

# %% [markdown]
# 리스트 변수 list_data의 요소를 writeText.txt 파일에 쓰시오.
# - writeText.txt는 새 파일로 생성
# - writeText.txt가 이미 존재한다면, 에러 발생되도록 하고 예외처리
# - 에러가 발생하면, '파일이 이미 존재합니다.' 출력
# - with문 사용
#
# << writeText.txt >>
# 1. one
# 2. two
# 3. three
# 4. four

# %%
list_data = ['one', 'two', 'three', 'four']

# %% [markdown]
# ## open 함수

# %%
## open 함수
## 쓰기 모드 : a - 추가, w - 덮어쓰기, x - 파일이 존재하지 않을 때, 파일 생성
try:
    with open('writeText.txt', 'x') as file:
        for idx, data in enumerate(list_data, 1):
            # print(f'{idx = }, {data = }')
            # print(f'{idx}. {data}')
            file.write(f'{idx}. {data}\n')
except:
    print('파일이 이미 존재합니다. 📜')
else:
    print('쓰기 작업 완료 😊')
# Out:
# 파일이 이미 존재합니다. 📜

# %% [markdown]
# ## Path 클래스

# %%
from pathlib import Path

file_path = Path('writeText.txt')

try:
    with file_path.open(mode='x', encoding='utf-8') as file:
        for idx, data in enumerate(list_data, 1):
            file.write(f'{idx}. {data}\n')
except:
    print('파일이 이미 존재합니다. 📜')
else:
    print('쓰기 작업 완료 😊')
# Out:
# 쓰기 작업 완료 😊
